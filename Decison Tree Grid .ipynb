# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse', 'absolute_error', 'poisson],
'max_features': ['sqrt','log2'],
'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# import matplotlib.pyplot as plt
# from sklearn import tree
# tree.plot_tree(regressor)
# plt.show()

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
print("The best parameter: {}".format(grid.best_params_))
table=pd.DataFrame.from_dict(re)
table
# Out:
# The best parameter: {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.030118      0.008088         0.007381    3.816085e-03
# 1        0.021342      0.009369         0.006783    3.116621e-03
# 2        0.038189      0.015111         0.006982    1.261163e-03
# 3        0.016754      0.004942         0.012767    1.307251e-02
# 4        0.023934      0.006707         0.006981    6.309779e-04
# 5        0.029719      0.015275         0.008180    1.162074e-03
# 6        0.018350      0.006295         0.005187    3.985883e-04
# 7        0.015756      0.005255         0.008778    4.608508e-03
# 8        0.068217      0.012111         0.011370    1.177803e-02
# 9        0.046674      0.017082         0.007381    2.491946e-03
# 10       0.064600      0.012735         0.009974    7.489855e-03
# 11       0.044879      0.003989         0.005984    7.136645e-07
# 12       0.017153      0.001466         0.006384    2.792740e-03
# 13       0.014760      0.004609         0.005785    1.162688e-03
# 14       0.025930      0.007802         0.011170    7.175400e-03
# 15       0.015226      0.004665         0.004987    4.101908e-07
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.738544
# 1   {'criterion': 'squared_error', 'max_features':...           0.674100
# 2   {'criterion': 'squared_error', 'max_features':...           0.740176
# 3   {'criterion': 'squared_error', 'max_features':...           0.718267
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.631090
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.643385
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.702811
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.713399
# 8   {'criterion': 'absolute_error', 'max_features'...           0.751259
# 9   {'criterion': 'absolute_error', 'max_features'...           0.693316
# 10  {'criterion': 'absolute_error', 'max_features'...           0.595144
# 11  {'criterion': 'absolute_error', 'max_features'...           0.737047
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.690021
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.732848
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.711808
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.695616
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.607091           0.651639           0.740636
# 1            0.560875           0.718338           0.707415
# 2            0.537840           0.758092           0.708886
# 3            0.547374           0.676212           0.653788
# 4            0.503814           0.529246           0.712689
# 5            0.514873           0.591503           0.561262
# 6            0.580417           0.715582           0.697301
# 7            0.555102           0.721111           0.715384
# 8            0.640374           0.685655           0.747344
# 9            0.505687           0.744942           0.647615
# 10           0.482055           0.707426           0.696671
# 11           0.588663           0.744413           0.655056
# 12           0.645279           0.464353           0.712107
# 13           0.525993           0.729172           0.589151
# 14           0.549477           0.766211           0.672483
# 15           0.427133           0.547154           0.636184
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.745864         0.696755        0.056848                3
# 1            0.546435         0.641432        0.073279               12
# 2            0.765349         0.702068        0.084395                2
# 3            0.702803         0.659689        0.060354                9
# 4            0.641136         0.603595        0.076877               14
# 5            0.631387         0.588482        0.046954               16
# 6            0.738165         0.686855        0.055047                5
# 7            0.646828         0.670365        0.063708                7
# 8            0.726668         0.710260        0.041988                1
# 9            0.730710         0.664454        0.086246                8
# 10           0.740267         0.644312        0.094527               11
# 11           0.750271         0.695090        0.063510                4
# 12           0.588640         0.620080        0.088583               13
# 13           0.648568         0.645146        0.080121               10
# 14           0.723185         0.684633        0.073884                6
# 15           0.658081         0.592834        0.096171               15

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:25
# BMI:1
# Children:12
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[14455.64405]
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
