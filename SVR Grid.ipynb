# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR 
param_grid = {'kernel':[ 'linear', 'poly', 'rbf'],
                'C':[10,100,200,1000,2000]
              }
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
# fitting the model for grid
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 200, 1000, 2000],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The best parameter is: {}".format(grid.best_params_))
# Out:
# The best parameter is: {'C': 1000, 'kernel': 'linear'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.219881      0.013974         0.029522        0.003764      10
# 1        0.193717      0.032237         0.028962        0.000987      10
# 2        0.179255      0.007540         0.094414        0.002558      10
# 3        0.392819      0.024788         0.026131        0.000399     100
# 4        0.174931      0.004351         0.028126        0.000977     100
# 5        0.174732      0.002706         0.095437        0.006080     100
# 6        0.630391      0.246748         0.026530        0.001017     200
# 7        0.184574      0.009561         0.028923        0.001092     200
# 8        0.172936      0.006811         0.091556        0.002849     200
# 9        1.320470      0.141000         0.026330        0.001017    1000
# 10       0.236572      0.013594         0.029322        0.001353    1000
# 11       0.190689      0.008817         0.091357        0.001017    1000
# 12       2.246322      0.284379         0.024733        0.005477    2000
# 13       0.271010      0.014263         0.029388        0.001481    2000
# 14       0.209173      0.010991         0.090625        0.002109    2000
#
#    param_kernel                           params  split0_test_score  \
# 0        linear    {'C': 10, 'kernel': 'linear'}          -0.018943
# 1          poly      {'C': 10, 'kernel': 'poly'}          -0.125153
# 2           rbf       {'C': 10, 'kernel': 'rbf'}          -0.110409
# 3        linear   {'C': 100, 'kernel': 'linear'}           0.559313
# 4          poly     {'C': 100, 'kernel': 'poly'}          -0.132885
# 5           rbf      {'C': 100, 'kernel': 'rbf'}          -0.160182
# 6        linear   {'C': 200, 'kernel': 'linear'}           0.597540
# 7          poly     {'C': 200, 'kernel': 'poly'}          -0.128637
# 8           rbf      {'C': 200, 'kernel': 'rbf'}          -0.164374
# 9        linear  {'C': 1000, 'kernel': 'linear'}           0.736398
# 10         poly    {'C': 1000, 'kernel': 'poly'}          -0.080527
# 11          rbf     {'C': 1000, 'kernel': 'rbf'}          -0.155430
# 12       linear  {'C': 2000, 'kernel': 'linear'}           0.682349
# 13         poly    {'C': 2000, 'kernel': 'poly'}          -0.020567
# 14          rbf     {'C': 2000, 'kernel': 'rbf'}          -0.143510
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.029886           0.022167           0.003112
# 1           -0.081505          -0.111907          -0.131602
# 2           -0.097459          -0.074488          -0.099597
# 3            0.521798           0.547691           0.538805
# 4           -0.082461          -0.129220          -0.139962
# 5           -0.107253          -0.123430          -0.137753
# 6            0.557538           0.586781           0.574764
# 7           -0.078468          -0.125003          -0.135484
# 8           -0.106426          -0.129065          -0.141841
# 9            0.675162           0.680002           0.699377
# 10          -0.028469          -0.073376          -0.086611
# 11          -0.098267          -0.123724          -0.137137
# 12           0.630642           0.750714           0.646368
# 13           0.035685          -0.011468          -0.024587
# 14          -0.087595          -0.113312          -0.128591
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.066653        -0.006086        0.034672                5
# 1           -0.179328        -0.125899        0.031794                9
# 2           -0.124428        -0.101276        0.016459                8
# 3            0.508518         0.535225        0.018122                4
# 4           -0.189219        -0.134749        0.033948               12
# 5           -0.209551        -0.147634        0.035511               14
# 6            0.555420         0.574409        0.016331                3
# 7           -0.182919        -0.130102        0.033205               10
# 8           -0.216445        -0.151630        0.037448               15
# 9            0.677952         0.693778        0.022955                1
# 10          -0.134493        -0.080695        0.033795                7
# 11          -0.206405        -0.144193        0.036262               13
# 12           0.722261         0.686467        0.045056                2
# 13          -0.076360        -0.019459        0.035693                6
# 14          -0.193992        -0.133400        0.035492               11

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:29
# BMI:12
# Children:1
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])#␣

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[3650.10558281]
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
